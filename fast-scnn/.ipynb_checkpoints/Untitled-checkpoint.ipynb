# %%
import os
import glob
import cv2
import numpy as np
import imgaug as ia
from matplotlib import pyplot as plt
from imgaug.augmentables.segmaps import SegmentationMapOnImage
import random
import itertools

# %%
a =os.getcwd()
print(a)
# Out:
# /qutub/models/semantic_segmentation_models-fast_scnn/fast-scnn

# %%
segs_path = a +'/dataset/kitti_seg/data_semantics/proc_data/train_labels/labels'
images_path = a +'/dataset/kitti_seg/data_semantics/proc_data/train_images/images'
print(segs_path)
# Out:
# /qutub/models/semantic_segmentation_models-fast_scnn/fast-scnn/dataset/kitti_seg/data_semantics/proc_data/train_labels/labels

# %%
segmentations  =  glob.glob( os.path.join(segs_path,"*.png")  ) 
images = glob.glob( os.path.join(images_path,"*.png")  )
image = images[0]
image
# Out:
# '/qutub/models/semantic_segmentation_models-fast_scnn/fast-scnn/dataset/kitti_seg/data_semantics/proc_data/train_images/images/000035_10.png'

# %%
segmentations_d = dict( zip(segmentations,segmentations ))
print(image)
# Out:
# /qutub/models/semantic_segmentation_models-fast_scnn/fast-scnn/dataset/kitti_seg/data_semantics/proc_data/train_images/images/000035_10.png

# %%
ret = []
seg_bnme = os.path.basename(image).replace(".jpg" , ".png").replace(".jpeg" , ".png")
seg = os.path.join( segs_path , seg_bnme  )

# %%
assert ( seg in segmentations_d ),  (im + " is present in "+images_path +" but "+seg_bnme+" is not found in "+segs_path + " . Make sure annotation image are in .png"  )

# %%
cvread = cv2.imread(images[0],1)
cvread1 = cv2.imread(image,0)
segmen = cv2.imread(segmentations[0],0)

# %%
cvread
# Out:
# array([[[255, 179, 113],
#         [255, 179, 113],
#         [255, 179, 113],
#         ...,
#         [ 84,  86, 104],
#         [ 75,  80,  95],
#         [ 75,  80,  95]],
#
#        [[255, 179, 113],
#         [255, 179, 113],
#         [255, 179, 113],
#         ...,
#         [ 62,  64,  82],
#         [ 59,  63,  81],
#         [ 59,  64,  79]],
#
#        [[255, 180, 114],
#         [255, 180, 114],
#         [255, 180, 114],
#         ...,
#         [ 50,  51,  71],
#         [ 45,  49,  68],
#         [ 45,  49,  67]],
#
#        ...,
#        [[ 93, 100, 103],
#         [ 96, 103, 106],
#         [103, 108, 111],
#         ...,
#         [ 26,  41,  33],
#         [ 19,  34,  26],
#         [ 18,  33,  25]],
#
#        [[102, 109, 112],
#         [104, 111, 114],
#         [110, 115, 118],
#         ...,
#         [ 26,  41,  33],
#         [ 23,  38,  30],
#         [ 22,  37,  29]],
#
#        [[104, 113, 116],
#         [106, 115, 118],
#         [111, 118, 121],
#         ...,
#         [ 25,  40,  32],
#         [ 27,  43,  32],
#         [ 26,  42,  31]]], dtype=uint8)

# %%
cvread[0]
# Out:
# array([[255, 179, 113],
#        [255, 179, 113],
#        [255, 179, 113],
#        ...,
#        [ 84,  86, 104],
#        [ 75,  80,  95],
#        [ 75,  80,  95]], dtype=uint8)

# %%
seg_aug = SegmentationMapOnImage(segmen, shape=cvread1.shape, nb_classes=34)

# %%
seg_output = seg_aug.resize((512,1024),interpolation='nearest')
# Out:
# /home/qutub1004/.conda/envs/fast-scnn/lib/python2.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Method `SegmentationMapOnImage.scale()` is deprecated. Use `SegmentationMapOnImage.resize()` instead. resize() has the exactly same interface.
#   """Entry point for launching an IPython kernel.

# %%
seg_output.shape
# Out:
# (375, 1242)

# %%
 arr_resized = ia.imresize_single_image(segmen, (512,1024), interpolation='nearest')

# %%
np.amax(arr_resized)
# Out:
# 33

# %%
plt.imshow(segmen)
plt.show()

# %%
plt.imshow(arr_resized)
plt.show()

# %%
arr_resized_1 = ia.imresize_single_image(arr_resized, (375,1242), interpolation='nearest')
plt.imshow(arr_resized_1)
plt.show()

# %%
arr_resized_1.shape
# Out:
# (375, 1242)

# %%
input_size = [512, 1024]
input_size
ret= []
# Out:
# [512, 1024]

# %%
ret
# Out:
# [('/qutub/models/semantic_segmentation_models-fast_scnn/fast-scnn/dataset/kitti_seg/data_semantics/proc_data/train_images/images/000035_10.png',
#   '/qutub/models/semantic_segmentation_models-fast_scnn/fast-scnn/dataset/kitti_seg/data_semantics/proc_data/train_labels/labels/000035_10.png'),
#  ('/qutub/models/semantic_segmentation_models-fast_scnn/fast-scnn/dataset/kitti_seg/data_semantics/proc_data/train_images/images/000181_10.png',
#   '/qutub/models/semantic_segmentation_models-fast_scnn/fast-scnn/dataset/kitti_seg/data_semantics/proc_data/train_labels/labels/000181_10.png'),
#  ('/qutub/models/semantic_segmentation_models-fast_scnn/fast-scnn/dataset/kitti_seg/data_semantics/proc_data/train_images/images/000129_10.png',
#   '/qutub/models/semantic_segmentation_models-fast_scnn/fast-scnn/dataset/kitti_seg/data_semantics/proc_data/train_labels/labels/000129_10.png')]

# %%
ret.append((images[2],segmentations[2]))

# %%
random.shuffle( ret )

# %%
zipped = itertools.cycle( ret  )

# %%
im , seg = next(zipped)

# %%
im
# Out:
# '/qutub/models/semantic_segmentation_models-fast_scnn/fast-scnn/dataset/kitti_seg/data_semantics/proc_data/train_images/images/000035_10.png'

# %%
seg
# Out:
# '/qutub/models/semantic_segmentation_models-fast_scnn/fast-scnn/dataset/kitti_seg/data_semantics/proc_data/train_labels/labels/000035_10.png'

# %%
im = cv2.imread(im , 1 )

# %%
image_1 = cv2.resize(im,(512,512))

# %%
im , seg = next(zipped)

# %%
im = cv2.imread(im , 1 )

# %%
plt.imshow(im)
plt.show()

# %%
im.shape
# Out:
#   File "<ipython-input-128-314c02e5487d>", line 1
#     im.(shape)
#        ^
# SyntaxError: invalid syntax

# %%
im , seg = next(zipped)
type(im)
# Out:
# str
